# %%
# %matplotlib inline
import module
from module import *
reload(module = module)
# Out:
# <module 'module' from '/home/ofialko/Documents/MLSP/6_SVM/module.py'>

# %% [markdown]
# ## Loading and Visualizing Data

# %%
data1 = loadmat('data1.mat')
X = data1['X']
y = data1['y']
y = y.astype('int')

# %%
plotData(X,y)

# %% [markdown]
# ## Training Linear SVM

# %%
C = 100
model = svmTrain(X, y.copy(), C, 'linearKernel', 1e-3, 20)
# Out:
# Training:
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...

# %%
visualizeBoundaryLinear(X,y,model)

# %% [markdown]
# ## Visualizing Dataset 2

# %%
data2 = loadmat('data2.mat')
X = data2['X']
y = data2['y']
y = y.astype('int')

# %%
plotData(X,y)

# %% [markdown]
# ## Training SVM with RBF Kernel (Dataset 2)

# %%
# SVM Parameters
C = 1; sigma = 0.1
# %time model= svmTrain(X, y.copy(), C,kernelFunction= 'gaussianKernel',sigma=sigma)
# Out:
# Training:
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...........................................................Done!
# CPU times: user 13.7 s, sys: 320 ms, total: 14 s
# Wall time: 13.6 s

# %%
visualizeBoundary(X,y,model)

# %% [markdown]
# ##  Visualizing Dataset 3

# %%
data3 = loadmat('data3.mat')
X = data3['X']
y = data3['y']
y = y.astype('int')

# %%
plotData(X,y)

# %% [markdown]
# ##  Training SVM with RBF Kernel (Dataset 3)

# %%
C=10; simga=0.1
model= svmTrain(X, y.copy(), C,  'gaussianKernel',sigma=sigma)
visualizeBoundary(X, y, model);
# Out:
# Training:
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...............................................................................
# ...........................Done!
